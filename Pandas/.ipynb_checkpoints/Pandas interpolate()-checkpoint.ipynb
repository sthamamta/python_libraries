# %%
import pandas as pd

# %%
#interpolate()
# it is used to fill NaN values in data frame

# %%
# parameters
#      method, axis, inplace, limit, limit_direction, limit_area

# %%
df= pd.read_csv('data/student_results.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        NaN            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     NaN
# 6        1007     12        4.0             6                     NaN
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
df.interpolate()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        3.5            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     2.0
# 6        1007     12        4.0             6                     2.0
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
type(df.Class[0])
# Out:
# numpy.int64

# %%
df1= pd.read_csv('data/student_results.csv',parse_dates=['Class'])
df1
# Out:
#    Student ID Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001    10        2.0             9                     3.0
# 1        1002    10        6.0             8                     2.0
# 2        1003    10        3.0             8                     2.0
# 3        1004    11        NaN            10                     1.0
# 4        1005    11        4.0             7                     2.0
# 5        1006    11       10.0             7                     NaN
# 6        1007    12        4.0             6                     NaN
# 7        1008    12       10.0             6                     2.0
# 8        1009    12        2.0             8                     2.0
# 9        1010    12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# 4               NaN          75
# ...

# %%
type(df.Class[0])
# Out:
# numpy.int64

# %%
type(df.Percentage[0])
# Out:
# numpy.int64

# %%
df2= pd.read_csv('data/student_results.csv',parse_dates=['Percentage'])
df2
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        NaN            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     NaN
# 6        1007     12        4.0             6                     NaN
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs Percentage
# 0               5.0         50
# 1               0.0         80
# 2               4.0         60
# 3               5.0         45
# 4               NaN         75
# ...

# %%
type(df.Percentage[0])
# Out:
# numpy.int64

# %%
df3= pd.read_csv('data/student_results.csv',index_col = 'Student ID')
df3
# Out:
#             Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Student ID
# 1001           10        2.0             9                     3.0
# 1002           10        6.0             8                     2.0
# 1003           10        3.0             8                     2.0
# 1004           11        NaN            10                     1.0
# 1005           11        4.0             7                     2.0
# 1006           11       10.0             7                     NaN
# 1007           12        4.0             6                     NaN
# 1008           12       10.0             6                     2.0
# 1009           12        2.0             8                     2.0
# 1010           12        6.0             9                     1.0
#
#             Mobile Games hrs  Percentage
# Student ID
# 1001                     5.0          50
# 1002                     0.0          80
# 1003                     4.0          60
# ...

# %%
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        NaN            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     NaN
# 6        1007     12        4.0             6                     NaN
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
# fill according to nearest values
df.interpolate(method='nearest')
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        3.0            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     2.0
# 6        1007     12        4.0             6                     2.0
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
# fill value according to polynomial value
df.interpolate(method='polynomial',order=2)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10   2.000000             9                3.000000
# 1        1002     10   6.000000             8                2.000000
# 2        1003     10   3.000000             8                2.000000
# 3        1004     11   1.194617            10                1.000000
# 4        1005     11   4.000000             7                2.000000
# 5        1006     11  10.000000             7                2.505101
# 6        1007     12   4.000000             6                2.161177
# 7        1008     12  10.000000             6                2.000000
# 8        1009     12   2.000000             8                2.000000
# 9        1010     12   6.000000             9                1.000000
#
#    Mobile Games hrs  Percentage
# 0          5.000000          50
# 1          0.000000          80
# 2          4.000000          60
# 3          5.000000          45
# ...

# %%
df.interpolate(method='polynomial',order=1)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        3.5            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     2.0
# 6        1007     12        4.0             6                     2.0
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
#using spline
df.interpolate(method='spline',order=2)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10    2.00000             9                3.000000
# 1        1002     10    6.00000             8                2.000000
# 2        1003     10    3.00000             8                2.000000
# 3        1004     11    2.08124            10                1.000000
# 4        1005     11    4.00000             7                2.000000
# 5        1006     11   10.00000             7                1.570175
# 6        1007     12    4.00000             6                1.514620
# 7        1008     12   10.00000             6                2.000000
# 8        1009     12    2.00000             8                2.000000
# 9        1010     12    6.00000             9                1.000000
#
#    Mobile Games hrs  Percentage
# 0          5.000000          50
# 1          0.000000          80
# 2          4.000000          60
# 3          5.000000          45
# ...

# %% [markdown]
# # Parameter

# %%
#1. method
#2. inplace
#3. axis
#4. limit
#5 limit_area
#6 limit_direction

# %%
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        NaN            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     NaN
# 6        1007     12        4.0             6                     NaN
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
df.interpolate()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        3.5            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     2.0
# 6        1007     12        4.0             6                     2.0
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
#checking datatypes of each columns
df.dtypes
# Out:
# Student ID                  int64
# Class                       int64
# Study hrs                 float64
# Sleeping hrs                int64
# Social Media usage hrs    float64
# Mobile Games hrs          float64
# Percentage                  int64
# dtype: object

# %%
#fills row-by-row
# for this datatype shouldnt be object datatype
df.interpolate(axis=1)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0   10.0        2.0           9.0                3.000000
# 1      1002.0   10.0        6.0           8.0                2.000000
# 2      1003.0   10.0        3.0           8.0                2.000000
# 3      1004.0   11.0       10.5          10.0                1.000000
# 4      1005.0   11.0        4.0           7.0                2.000000
# 5      1006.0   11.0       10.0           7.0               36.666667
# 6      1007.0   12.0        4.0           6.0               30.666667
# 7      1008.0   12.0       10.0           6.0                2.000000
# 8      1009.0   12.0        2.0           8.0                2.000000
# 9      1010.0   12.0        6.0           9.0                1.000000
#
#    Mobile Games hrs  Percentage
# 0          5.000000        50.0
# 1          0.000000        80.0
# 2          4.000000        60.0
# 3          5.000000        45.0
# ...

# %%
#using limit
#maximum no of NaN values to be filled

# %%
df.interpolate(limit=2)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        3.5            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     2.0
# 6        1007     12        4.0             6                     2.0
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
#using limit_direction
df.interpolate(limit_direction='forward')
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        3.5            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     2.0
# 6        1007     12        4.0             6                     2.0
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
df.interpolate(limit=1,limit_direction='both')
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        3.5            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     2.0
# 6        1007     12        4.0             6                     2.0
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
df.interpolate(limit_area='inside')
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        3.5            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     2.0
# 6        1007     12        4.0             6                     2.0
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...

# %%
df.interpolate(limit_area='outside')
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10        2.0             9                     3.0
# 1        1002     10        6.0             8                     2.0
# 2        1003     10        3.0             8                     2.0
# 3        1004     11        NaN            10                     1.0
# 4        1005     11        4.0             7                     2.0
# 5        1006     11       10.0             7                     NaN
# 6        1007     12        4.0             6                     NaN
# 7        1008     12       10.0             6                     2.0
# 8        1009     12        2.0             8                     2.0
# 9        1010     12        6.0             9                     1.0
#
#    Mobile Games hrs  Percentage
# 0               5.0          50
# 1               0.0          80
# 2               4.0          60
# 3               5.0          45
# ...
